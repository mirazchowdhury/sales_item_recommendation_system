Shahida Khatun

Shahida Jahan

Shahida Chowdhury

Rashida Akter

Rashida Begum

Rashida Khatun

Rashida Jahan

Rashida Chowdhury

Halima Akter

Halima Begum

Halima Khatun

Halima Jahan

Halima Chowdhury

Amina Akter

Amina Begum

Amina Khatun

Amina Jahan

Amina Chowdhury

Khadija Akter

Khadija Begum

Khadija Khatun

Khadija Jahan

Khadija Chowdhury

Rahima Akter

Rahima Begum

Rahima Khatun

Rahima Jahan

Rahima Chowdhury

Karima Akter

Karima Begum

Karima Khatun

Karima Jahan

Karima Chowdhury

Saleha Akter

Saleha Begum

Saleha Khatun

Saleha Jahan

Saleha Chowdhury

Maleka Akter

Maleka Begum

Maleka Khatun

Maleka Jahan

Maleka Chowdhury

Zobeda Akter

Zobeda Begum

Zobeda Khatun

Zobeda Jahan

Zobeda Chowdhury
"""

# ২. ডেটা ক্লিন করা (ফাঁকা লাইন বাদ দেওয়া এবং হোয়াইটস্পেস রিমুভ করা)
name_list = [name.strip() for name in raw_names.split('\n') if name.strip()]

# ৩. Pandas DataFrame তৈরি করা
df = pd.DataFrame({'customer_name': name_list})

# ৪. ডুপ্লিকেট রিমুভ করা (অপশনাল: যদি লিস্টে একই নাম দুইবার থাকে এবং আপনি তাদের জন্য আলাদা ID না চান)
# df = df.drop_duplicates(subset=['customer_name']).reset_index(drop=True)

# ৫. সিকোয়েনশিয়াল ইউনিক Customer ID জেনারেট করা (যেমন: CUST-0001, CUST-0002)
df['customer_id'] = ['CUST-' + str(i).zfill(4) for i in range(1, len(df) + 1)]

# ৬. সুন্দরভাবে দেখানোর জন্য কলামগুলো রি-অর্ডার করা
df = df[['customer_id', 'customer_name']]

# ৭. প্রথম ১০টি এবং শেষের ৫টি রো (Row) প্রিন্ট করে চেক করা
print("First 10 Customers:")
display(df.head(10))

print("\nLast 5 Customers:")
display(df.tail(5))

# Optional: Save it to a CSV file
folder_name = 'data'

# যদি folder না থাকে, তবে তৈরি হবে
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    
# Folder-এর ভেতরে save করার path
file_path = os.path.join(folder_name, 'customer_list.csv')

# Save করুন
df.to_csv(file_path, index=False)
# Out:
# First 10 Customers:
#   customer_id  customer_name
# 0   CUST-0001   Tariq Rahman
# 1   CUST-0002    Tariq Islam
# 2   CUST-0003    Tariq Uddin
# 3   CUST-0004    Tariq Ahmed
# 4   CUST-0005      Tariq Ali
# 5   CUST-0006  Shafiq Rahman
# 6   CUST-0007   Shafiq Islam
# 7   CUST-0008   Shafiq Uddin
# 8   CUST-0009   Shafiq Ahmed
# 9   CUST-0010     Shafiq Ali
# Last 5 Customers:
#     customer_id     customer_name
# 500   CUST-0501      Zobeda Akter
# 501   CUST-0502      Zobeda Begum
# 502   CUST-0503     Zobeda Khatun
# 503   CUST-0504      Zobeda Jahan
# 504   CUST-0505  Zobeda Chowdhury
